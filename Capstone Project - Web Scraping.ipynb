# %% [markdown]
# # Creating the Dataset

# %% [markdown]
# ## Imports

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## Webscraping the Democratic Party's Tweets

# %%
# %%time
bidenl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:JoeBiden since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    bidenl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems1 = pd.DataFrame(bidenl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems1
# Out:
# CPU times: user 7.63 s, sys: 456 ms, total: 8.09 s
# Wall time: 2min 26s
#                           Date             Tweet ID  \
# 0    2022-11-01 13:55:03+00:00  1587443101790048258
# 1    2022-11-01 01:27:00+00:00  1587254848940085253
# 2    2022-10-31 22:30:02+00:00  1587210314663215105
# 3    2022-10-31 20:29:01+00:00  1587179858236305408
# 4    2022-10-31 18:22:05+00:00  1587147915050500103
# ...                        ...                  ...
# 6250 2017-02-06 01:29:42+00:00   828415338886942721
# 6251 2017-02-02 22:33:55+00:00   827283937000951808
# 6252 2017-02-01 16:25:37+00:00   826828864009678850
# 6253 2017-02-01 14:57:38+00:00   826806724006965248
# 6254 2017-02-01 14:57:19+00:00   826806641370791936
#
#                                                   Tweet  Username
# 0     One more week until Election Day. \n\nLet’s do...  JoeBiden
# 1     Democrats will protect Social Security.\nWe’ll...  JoeBiden
# 2     With Election Day right around the corner, I’m...  JoeBiden
# ...

# %%
# %%time
bidenl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:POTUS since:2021-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    bidenl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems2 = pd.DataFrame(bidenl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems2
# Out:
# CPU times: user 4.79 s, sys: 294 ms, total: 5.08 s
# Wall time: 1min 24s
#                           Date             Tweet ID  \
# 0    2022-11-01 13:30:25+00:00  1587436902122196995
# 1    2022-11-01 01:45:02+00:00  1587259387525177346
# 2    2022-11-01 01:27:28+00:00  1587254966309240841
# 3    2022-10-31 22:00:01+00:00  1587202758515499010
# 4    2022-10-31 21:05:51+00:00  1587189129271562241
# ...                        ...                  ...
# 4182 2021-01-21 02:25:00+00:00  1352079719945162752
# 4183 2021-01-21 01:57:34+00:00  1352072818847068163
# 4184 2021-01-20 23:03:55+00:00  1352029117974278145
# 4185 2021-01-20 18:31:00+00:00  1351960433905700864
# 4186 2021-01-20 17:36:59+00:00  1351946842838347776
#
#                                                   Tweet Username
# 0     It’s time for oil companies to stop the war pr...    POTUS
# 1              Happy Halloween! https://t.co/zsNvQPDCs3    POTUS
# 2     In the last six months, 6 of the largest oil c...    POTUS
# ...

# %%
# %%time
sandersl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:BernieSanders since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    sandersl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems3 = pd.DataFrame(sandersl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems3
# Out:
# CPU times: user 9.85 s, sys: 550 ms, total: 10.4 s
# Wall time: 3min 14s
#                           Date             Tweet ID  \
# 0    2022-11-01 15:10:24+00:00  1587462065899425793
# 1    2022-11-01 15:10:23+00:00  1587462060350357504
# 2    2022-10-31 19:59:53+00:00  1587172529789091841
# 3    2022-10-31 16:05:00+00:00  1587113417063759878
# 4    2022-10-30 23:33:46+00:00  1586863963283009536
# ...                        ...                  ...
# 8050 2017-01-22 16:50:01+00:00   823211123960872962
# 8051 2017-01-21 16:18:55+00:00   822840912434831360
# 8052 2017-01-21 00:39:01+00:00   822604378142081027
# 8053 2017-01-20 15:23:12+00:00   822464499718520836
# 8054 2017-01-20 02:17:51+00:00   822266860716617730
#
#                                                   Tweet       Username
# 0     RSVP to join us in Eau Claire: https://t.co/UQ...  BernieSanders
# 1     This weekend, I am headed to Wisconsin to rall...  BernieSanders
# ...

# %%
# %%time
sandersl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenSanders since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    sandersl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems4 = pd.DataFrame(sandersl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems4
# Out:
# CPU times: user 7.42 s, sys: 409 ms, total: 7.83 s
# Wall time: 2min 28s
#                           Date             Tweet ID  \
# 0    2022-10-31 17:18:46+00:00  1587131980637954048
# 1    2022-10-30 23:31:23+00:00  1586863364743073792
# 2    2022-10-28 19:46:55+00:00  1586082101454962688
# 3    2022-10-28 18:19:57+00:00  1586060216356962307
# 4    2022-10-28 16:53:57+00:00  1586038572334960640
# ...                        ...                  ...
# 6047 2017-01-21 00:18:01+00:00   822599091834208257
# 6048 2017-01-21 00:09:12+00:00   822596873135525888
# 6049 2017-01-20 23:58:13+00:00   822594111240814592
# 6050 2017-01-20 15:06:02+00:00   822460180432420866
# 6051 2017-01-20 14:26:10+00:00   822450149997891585
#
#                                                   Tweet    Username
# 0     President Biden is right. At a time when Exxon...  SenSanders
# 1     Today, the people of Brazil have voted for dem...  SenSanders
# ...

# %%
# %%time
pelosil1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SpeakerPelosi since:2019-01-03 lang:en').get_items()):
    if i == maxTweets:
        break
    pelosil1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems5 = pd.DataFrame(pelosil1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems5
# Out:
# CPU times: user 5.98 s, sys: 334 ms, total: 6.31 s
# Wall time: 1min 50s
#                           Date             Tweet ID  \
# 0    2022-11-01 00:35:09+00:00  1587241802431860736
# 1    2022-10-30 01:30:59+00:00  1586531076192993280
# 2    2022-10-30 01:30:59+00:00  1586531074511089664
# 3    2022-10-27 22:08:18+00:00  1585755291316113411
# 4    2022-10-27 15:10:06+00:00  1585650050734120960
# ...                        ...                  ...
# 4908 2019-01-03 20:05:11+00:00  1080918011366834176
# 4909 2019-01-03 19:54:48+00:00  1080915398873284608
# 4910 2019-01-03 19:48:12+00:00  1080913740177068032
# 4911 2019-01-03 17:03:04+00:00  1080872181666664448
# 4912 2019-01-03 00:02:02+00:00  1080615229678125057
#
#                                                   Tweet       Username
# 0     Since the horrific attack on Paul early Friday...  SpeakerPelosi
# 1     Read my letter to my colleagues in the Congres...  SpeakerPelosi
# ...

# %%
# %%time
pelosil2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:TeamPelosi since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    pelosil2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems6 = pd.DataFrame(pelosil2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems6
# Out:
# CPU times: user 6.09 s, sys: 346 ms, total: 6.44 s
# Wall time: 2min 10s
#                           Date             Tweet ID  \
# 0    2022-10-31 21:25:00+00:00  1587193946861469697
# 1    2022-10-31 16:30:22+00:00  1587119801666879488
# 2    2022-10-30 01:20:00+00:00  1586528311102013440
# 3    2022-10-28 01:30:05+00:00  1585806075714060288
# 4    2022-10-27 21:00:29+00:00  1585738225233993728
# ...                        ...                  ...
# 5040 2017-01-21 23:30:03+00:00   822949407666696192
# 5041 2017-01-21 19:37:54+00:00   822890986879811584
# 5042 2017-01-21 17:48:06+00:00   822863355631300610
# 5043 2017-01-20 23:28:45+00:00   822586693987528705
# 5044 2017-01-20 17:46:24+00:00   822500541100130304
#
#                                                   Tweet    Username
# 0     Social Security is your money. Democrats hear ...  TeamPelosi
# 1     We all have a role to play in defending our De...  TeamPelosi
# ...

# %%
# %%time
schumerl1 = []
maxTweets = 20000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenSchumer since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    schumerl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems7 = pd.DataFrame(schumerl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems7
# Out:
# CPU times: user 12 s, sys: 698 ms, total: 12.7 s
# Wall time: 4min 16s
#                            Date             Tweet ID  \
# 0     2022-10-31 22:15:34+00:00  1587206672933691392
# 1     2022-10-31 20:15:01+00:00  1587176336786866177
# 2     2022-10-29 19:15:10+00:00  1586436499247353857
# 3     2022-10-29 13:56:49+00:00  1586356384777441280
# 4     2022-10-28 20:50:52+00:00  1586098194689073152
# ...                         ...                  ...
# 10149 2017-01-22 13:22:22+00:00   823158869761343488
# 10150 2017-01-20 22:52:21+00:00   822577533845704706
# 10151 2017-01-20 22:20:09+00:00   822569430672666624
# 10152 2017-01-20 00:44:30+00:00   822243371561447424
# 10153 2017-01-20 00:40:56+00:00   822242471883243520
#
#                                                    Tweet    Username
# 0      Trick-or-treating with Mickey and Minnie! http...  SenSchumer
# 1      Big Oil is raking in profits.\n\nRepublicans w...  SenSchumer
# ...

# %%
# %%time
schumerl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:chuckschumer since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    schumerl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems8 = pd.DataFrame(schumerl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems8
# Out:
# CPU times: user 761 ms, sys: 37.8 ms, total: 798 ms
# Wall time: 14.2 s
#                          Date             Tweet ID  \
# 0   2022-11-01 15:18:51+00:00  1587464191128002560
# 1   2022-10-30 23:01:00+00:00  1586855718493331459
# 2   2022-10-29 20:35:04+00:00  1586456606895546368
# 3   2022-10-28 20:39:20+00:00  1586095292273033218
# 4   2022-10-25 23:00:02+00:00  1585043534767620097
# ..                        ...                  ...
# 508 2017-05-12 17:46:02+00:00   863087888875085824
# 509 2017-04-12 02:29:04+00:00   851985491264237568
# 510 2017-02-25 21:38:49+00:00   835604993457733632
# 511 2017-02-25 21:36:12+00:00   835604333718867968
# 512 2017-02-25 14:18:01+00:00   835494062862008320
#
#                                                  Tweet      Username
# 0    One week left until one of the most important ...  chuckschumer
# 1    I’m so proud of all we’ve done to deliver for ...  chuckschumer
# 2    📅Early Voting in New York begins TODAY!\n\n🗳Do...  chuckschumer
# ...

# %%
# %%time
harrisl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:VP since:2021-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    harrisl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems9 = pd.DataFrame(harrisl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems9
# Out:
# CPU times: user 2.31 s, sys: 148 ms, total: 2.45 s
# Wall time: 11min 17s
#                           Date             Tweet ID  \
# 0    2022-10-31 23:44:30+00:00  1587229053408481280
# 1    2022-10-31 20:55:38+00:00  1587186559673110529
# 2    2022-10-31 13:35:00+00:00  1587075668910739465
# 3    2022-10-29 23:15:00+00:00  1586496856393220096
# 4    2022-10-29 17:41:00+00:00  1586412801698009090
# ...                        ...                  ...
# 1966 2021-01-21 15:17:19+00:00  1352274079051620360
# 1967 2021-01-21 03:21:44+00:00  1352093996227637249
# 1968 2021-01-21 00:56:49+00:00  1352057526641172483
# 1969 2021-01-20 18:11:22+00:00  1351955494978646018
# 1970 2021-01-20 17:02:10+00:00  1351938078643003393
#
#                                                   Tweet Username
# 0              Happy Halloween! https://t.co/vTcnR6zcEp       VP
# 1     We stand with the people of India who are mour...       VP
# 2     Here’s what we’ve done so far:\n— provided rel...       VP
# ...

# %%
# %%time
harrisl2 = []
maxTweets = 20000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:KamalaHarris since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    harrisl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems10 = pd.DataFrame(harrisl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems10
# Out:
# CPU times: user 11.7 s, sys: 789 ms, total: 12.5 s
# Wall time: 4min 32s
#                            Date             Tweet ID  \
# 0     2022-11-01 14:39:00+00:00  1587454163612475392
# 1     2022-10-30 22:03:25+00:00  1586841229643612160
# 2     2022-10-30 17:21:00+00:00  1586770156277178368
# 3     2022-10-30 16:38:00+00:00  1586759334993739776
# 4     2022-10-29 18:14:00+00:00  1586421106566651905
# ...                         ...                  ...
# 10823 2017-01-20 16:09:26+00:00   822476135057526784
# 10824 2017-01-20 14:53:00+00:00   822456900910546945
# 10825 2017-01-20 14:02:30+00:00   822444194321092608
# 10826 2017-01-20 01:52:58+00:00   822260600118120449
# 10827 2017-01-20 00:01:11+00:00   822232466786283521
#
#                                                    Tweet      Username
# 0      One week from today, Americans across the coun...  KamalaHarris
# 1      You have the power to stop Republican-led atta...  KamalaHarris
# ...

# %%
# %%time
warrenl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenWarren since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    warrenl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems11 = pd.DataFrame(warrenl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems11
# Out:
# CPU times: user 8.1 s, sys: 551 ms, total: 8.65 s
# Wall time: 3min 2s
#                           Date             Tweet ID  \
# 0    2022-11-01 13:59:06+00:00  1587444121194594304
# 1    2022-11-01 00:16:50+00:00  1587237191293468673
# 2    2022-10-31 21:17:58+00:00  1587192177058275328
# 3    2022-10-31 17:30:24+00:00  1587134907561791488
# 4    2022-10-31 13:54:06+00:00  1587080477340565504
# ...                        ...                  ...
# 7229 2017-01-23 21:11:27+00:00   823639306543710209
# 7230 2017-01-20 23:27:23+00:00   822586351744847873
# 7231 2017-01-20 23:26:15+00:00   822586064246370308
# 7232 2017-01-20 23:25:30+00:00   822585874718330881
# 7233 2017-01-20 23:24:21+00:00   822585584942202882
#
#                                                   Tweet   Username
# 0     Leading healthcare providers reveal in my new ...  SenWarren
# 1     Blocking the @penguinrandom merger with @simon...  SenWarren
# ...

# %%
# %%time
warrenl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:ewarren since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    warrenl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems12 = pd.DataFrame(warrenl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems12
# Out:
# CPU times: user 10.8 s, sys: 707 ms, total: 11.5 s
# Wall time: 4min 5s
#                           Date             Tweet ID  \
# 0    2022-11-01 13:48:55+00:00  1587441560215429120
# 1    2022-10-31 23:48:03+00:00  1587229947885764608
# 2    2022-10-31 21:47:22+00:00  1587199575193968644
# 3    2022-10-31 18:08:35+00:00  1587144516489936897
# 4    2022-10-31 14:10:17+00:00  1587084548369702913
# ...                        ...                  ...
# 9566 2017-02-04 19:57:51+00:00   827969435927453696
# 9567 2017-02-04 19:56:34+00:00   827969112710184966
# 9568 2017-01-23 02:47:06+00:00   823361387808354304
# 9569 2017-01-21 20:29:31+00:00   822903977570340868
# 9570 2017-01-20 14:39:50+00:00   822453588572176386
#
#                                                   Tweet Username
# 0     At least 10,000 decisions that the government ...  ewarren
# 1     Bailey and I wish you a safe and happy Hallowe...  ewarren
# 2     Thank you, President @BarackObama, for making ...  ewarren
# ...

# %%
# %%time
aocl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:AOC since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    aocl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems13 = pd.DataFrame(aocl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems13
# Out:
# CPU times: user 10.7 s, sys: 587 ms, total: 11.3 s
# Wall time: 3min 55s
#                           Date             Tweet ID  \
# 0    2022-10-31 21:19:45+00:00  1587192628038307840
# 1    2022-10-31 18:23:13+00:00  1587148199265026057
# 2    2022-10-31 02:39:12+00:00  1586910629729804288
# 3    2022-10-29 20:23:39+00:00  1586453732057047040
# 4    2022-10-29 13:26:03+00:00  1586348640435855360
# ...                        ...                  ...
# 8346 2017-05-17 12:26:40+00:00   864819456069042176
# 8347 2017-05-17 12:11:38+00:00   864815671288442881
# 8348 2017-05-16 21:13:11+00:00   864589569823518720
# 8349 2017-05-16 16:14:07+00:00   864514309564616704
# 8350 2017-05-09 00:54:36+00:00   861746190228086784
#
#                                                   Tweet Username
# 0     Shamefully, AIPAC is working for Republican co...      AOC
# 1     Proud to represent one of the safest places in...      AOC
# 2     Notice how Republicans are frothing at the mou...      AOC
# ...

# %%
# %%time
aocl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RepAOC since:2019-01-03 lang:en').get_items()):
    if i == maxTweets:
        break
    aocl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems14 = pd.DataFrame(aocl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems14
# Out:
# CPU times: user 1.41 s, sys: 83.2 ms, total: 1.5 s
# Wall time: 28.2 s
#                           Date             Tweet ID  \
# 0    2022-10-27 19:46:01+00:00  1585719485516115968
# 1    2022-10-26 17:03:03+00:00  1585316088887201792
# 2    2022-10-24 14:35:57+00:00  1584554293558120448
# 3    2022-10-20 13:37:00+00:00  1583089904531144705
# 4    2022-10-18 20:32:04+00:00  1582469585680289792
# ...                        ...                  ...
# 1071 2019-01-14 20:48:28+00:00  1084915172504989696
# 1072 2019-01-13 02:38:43+00:00  1084278540596662272
# 1073 2019-01-13 02:36:00+00:00  1084277855016706049
# 1074 2019-01-09 18:03:38+00:00  1083061753322397698
# 1075 2019-01-08 18:30:41+00:00  1082706172623376384
#
#                                                   Tweet Username
# 0     Thank you @HispanicCaucus for supporting the I...   RepAOC
# 1     A federal appeals court has temporarily halted...   RepAOC
# 2     Happy Diwali to everyone celebrating in NY-14 ...   RepAOC
# ...

# %%
# %%time
watersl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RepMaxineWaters since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    watersl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems15 = pd.DataFrame(watersl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems15
# Out:
# CPU times: user 1.32 s, sys: 79.5 ms, total: 1.4 s
# Wall time: 22.8 s
#                           Date             Tweet ID  \
# 0    2022-10-31 21:42:04+00:00  1587198241229180929
# 1    2022-10-31 17:18:16+00:00  1587131854469095430
# 2    2022-10-28 21:51:58+00:00  1586113570668175360
# 3    2022-10-25 21:43:08+00:00  1585024184866189312
# 4    2022-10-21 22:45:38+00:00  1583590359963090944
# ...                        ...                  ...
# 1091 2017-01-23 16:18:49+00:00   823565660945088512
# 1092 2017-01-21 21:12:12+00:00   822914716662165504
# 1093 2017-01-21 15:34:29+00:00   822829729795473409
# 1094 2017-01-21 14:25:27+00:00   822812355704881152
# 1095 2017-01-20 04:30:29+00:00   822300240262795265
#
#                                                   Tweet         Username
# 0     Halloween is meant to be a fun time! Mimicking...  RepMaxineWaters
# 1     So happy to hear that Paul Pelosi is recoverin...  RepMaxineWaters
# ...

# %%
# %%time
watersl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:MaxineWaters since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    watersl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems16 = pd.DataFrame(watersl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems16
# Out:
# CPU times: user 1.45 s, sys: 84.2 ms, total: 1.53 s
# Wall time: 26.5 s
#                           Date             Tweet ID  \
# 0    2022-02-11 16:19:39+00:00  1492171484902539272
# 1    2021-06-29 14:19:07+00:00  1409879103629664264
# 2    2021-06-19 18:01:11+00:00  1406311112828755969
# 3    2021-06-19 15:57:36+00:00  1406280011791933442
# 4    2020-12-11 20:18:17+00:00  1337491917144207363
# ...                        ...                  ...
# 1143 2017-08-11 17:11:41+00:00   896056538762100738
# 1144 2017-04-17 19:26:50+00:00   854053558186102784
# 1145 2017-04-17 19:20:40+00:00   854052004951445504
# 1146 2017-04-17 19:19:04+00:00   854051604164730882
# 1147 2017-04-12 22:36:01+00:00   852289229572931585
#
#                                                   Tweet      Username
# 0     Rep. Hmm Rogers apologizing after "Kiss my a**...  MaxineWaters
# 1     .@ToneStith, you don’t need a do over! Auntie ...  MaxineWaters
# ...

# %%
# %%time
bookerl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:CoryBooker since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    bookerl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems17 = pd.DataFrame(bookerl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems17
# Out:
# CPU times: user 8.28 s, sys: 451 ms, total: 8.73 s
# Wall time: 2min 52s
#                           Date             Tweet ID  \
# 0    2022-10-31 19:04:42+00:00  1587158640145874945
# 1    2022-10-31 11:49:47+00:00  1587049189116108802
# 2    2022-10-31 11:49:46+00:00  1587049185236451331
# 3    2022-10-30 17:47:27+00:00  1586776811517710338
# 4    2022-10-29 11:40:35+00:00  1586322101044060160
# ...                        ...                  ...
# 6616 2017-01-23 15:00:16+00:00   823545893278326784
# 6617 2017-01-23 13:50:19+00:00   823528292393320449
# 6618 2017-01-21 14:28:35+00:00   822813143210557441
# 6619 2017-01-21 13:03:38+00:00   822791766562787329
# 6620 2017-01-20 13:20:31+00:00   822433627095109633
#
#                                                   Tweet    Username
# 0     New Jersey – for the first time ever in a midt...  CoryBooker
# 1     And yes, this is my 9th anniversary of being s...  CoryBooker
# ...

# %%
# %%time
bookerl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenBooker since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    bookerl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems18 = pd.DataFrame(bookerl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems18
# Out:
# CPU times: user 4.46 s, sys: 247 ms, total: 4.71 s
# Wall time: 1min 27s
#                           Date             Tweet ID  \
# 0    2022-10-28 16:40:55+00:00  1586035294444597248
# 1    2022-10-28 15:40:51+00:00  1586020176566571009
# 2    2022-10-27 18:40:09+00:00  1585702912008888322
# 3    2022-10-27 14:42:29+00:00  1585643098314457089
# 4    2022-10-27 14:06:16+00:00  1585633987057176579
# ...                        ...                  ...
# 3503 2017-01-23 23:37:22+00:00   823676026802831362
# 3504 2017-01-20 22:21:01+00:00   822569649481125888
# 3505 2017-01-20 22:10:25+00:00   822566982486814720
# 3506 2017-01-20 21:23:42+00:00   822555226486046721
# 3507 2017-01-20 04:21:01+00:00   822297856602152961
#
#                                                   Tweet   Username
# 0     Today I joined @GovMurphy, @SenatorMenendez, @...  SenBooker
# 1     I'm profoundly disturbed to hear Speaker Pelos...  SenBooker
# ...

# %%
# %%time
jayapall1 = []
maxTweets = 20000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RepJayapal since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    jayapall1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems19 = pd.DataFrame(jayapall1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems19
# Out:
# CPU times: user 22.4 s, sys: 1.14 s, total: 23.6 s
# Wall time: 7min 53s
#                            Date             Tweet ID  \
# 0     2022-11-01 14:30:00+00:00  1587451897987858433
# 1     2022-10-31 21:30:00+00:00  1587195206868213760
# 2     2022-10-31 17:15:00+00:00  1587131033094393858
# 3     2022-10-31 15:00:02+00:00  1587097066391609346
# 4     2022-10-31 04:39:20+00:00  1586940863527407617
# ...                         ...                  ...
# 17925 2017-01-20 16:55:38+00:00   822487764155281410
# 17926 2017-01-20 16:40:53+00:00   822484051244163072
# 17927 2017-01-20 02:19:20+00:00   822267236396085248
# 17928 2017-01-20 01:19:31+00:00   822252183538147328
# 17929 2017-01-20 01:03:58+00:00   822248267853352960
#
#                                                    Tweet    Username
# 0      ⚠Election Day is one week away⚠\n\nMake a plan...  RepJayapal
# 1      Don't miss your chance! The PSLF waiver closes...  RepJayapal
# ...

# %%
# %%time
jayapall2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:PramilaJayapal since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    jayapall2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems20 = pd.DataFrame(jayapall2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems20
# Out:
# CPU times: user 7.93 s, sys: 399 ms, total: 8.33 s
# Wall time: 2min 46s
#                           Date             Tweet ID  \
# 0    2022-11-01 15:16:02+00:00  1587463481930006530
# 1    2022-11-01 01:39:00+00:00  1587257869224890368
# 2    2022-10-31 23:38:00+00:00  1587227418615549954
# 3    2022-10-31 21:22:00+00:00  1587193193837350912
# 4    2022-10-31 18:25:01+00:00  1587148653973512192
# ...                        ...                  ...
# 6412 2017-01-20 14:59:24+00:00   822458511439302656
# 6413 2017-01-20 14:57:09+00:00   822457946877599744
# 6414 2017-01-20 04:33:20+00:00   822300959367757824
# 6415 2017-01-20 04:00:19+00:00   822292648270512129
# 6416 2017-01-20 00:31:24+00:00   822240072951013376
#
#                                                   Tweet        Username
# 0     If the Republicans control Congress, they’ll t...  PramilaJayapal
# 1     You know what scares me the most this Hallowee...  PramilaJayapal
# ...

# %%
# %%time
klobucharl1 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:amyklobuchar since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    klobucharl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems21 = pd.DataFrame(klobucharl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems21
# Out:
# CPU times: user 12.4 s, sys: 621 ms, total: 13 s
# Wall time: 4min 7s
#                           Date             Tweet ID  \
# 0    2022-11-01 04:40:58+00:00  1587303661704605699
# 1    2022-11-01 02:49:15+00:00  1587275548044263424
# 2    2022-11-01 01:38:07+00:00  1587257648314982400
# 3    2022-10-31 20:15:12+00:00  1587176382060191748
# 4    2022-10-31 17:42:30+00:00  1587137952206970886
# ...                        ...                  ...
# 9790 2017-01-21 19:47:04+00:00   822893294178959361
# 9791 2017-01-21 15:34:46+00:00   822829799689351170
# 9792 2017-01-21 14:02:21+00:00   822806542227476481
# 9793 2017-01-20 17:32:19+00:00   822496994249867268
# 9794 2017-01-20 04:54:58+00:00   822306400130871299
#
#                                                   Tweet      Username
# 0     Best Halloween moon ever! (Taken from airplane...  amyklobuchar
# 1     If anyone has Nevada's back, it's Catherine @C...  amyklobuchar
# ...

# %%
# %%time
klobucharl2 = []
maxTweets = 10000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenAmyKlobuchar since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    klobucharl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems22 = pd.DataFrame(klobucharl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems22
# Out:
# CPU times: user 2.07 s, sys: 115 ms, total: 2.18 s
# Wall time: 42.5 s
#                           Date             Tweet ID  \
# 0    2022-10-28 00:27:03+00:00  1585790209916305408
# 1    2022-10-26 21:10:42+00:00  1585378412017094657
# 2    2022-10-26 02:35:19+00:00  1585097713783541762
# 3    2022-10-18 23:53:21+00:00  1582520239157563393
# 4    2022-10-16 20:03:47+00:00  1581737689526595584
# ...                        ...                  ...
# 1597 2018-02-07 22:08:24+00:00   961361025688834048
# 1598 2018-01-25 00:01:31+00:00   956316064614420480
# 1599 2018-01-12 02:31:23+00:00   951642736515538945
# 1600 2018-01-09 18:24:36+00:00   950795458062028801
# 1601 2018-01-09 18:03:22+00:00   950790112719368192
#
#                                                   Tweet         Username
# 0     Medicare Open Enrollment has begun. If you’re ...  SenAmyKlobuchar
# 1     I hope everyone gets a chance to enjoy the fal...  SenAmyKlobuchar
# ...

# %%
# %%time
demsl1 = []
maxTweets = 20000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:TheDemocrats since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    demsl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
dems23 = pd.DataFrame(demsl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

dems23
# Out:
# CPU times: user 17.4 s, sys: 888 ms, total: 18.2 s
# Wall time: 5min 45s
#                            Date             Tweet ID  \
# 0     2022-11-01 15:30:07+00:00  1587467028243386374
# 1     2022-11-01 14:05:04+00:00  1587445621178474499
# 2     2022-11-01 01:29:00+00:00  1587255352810160128
# 3     2022-11-01 00:19:01+00:00  1587237741665869827
# 4     2022-10-31 22:35:00+00:00  1587211564612030464
# ...                         ...                  ...
# 14337 2017-01-21 13:44:43+00:00   822802106788835328
# 14338 2017-01-20 18:09:38+00:00   822506385984417799
# 14339 2017-01-20 17:56:37+00:00   822503110274859008
# 14340 2017-01-20 17:00:45+00:00   822489051932594176
# 14341 2017-01-20 14:48:44+00:00   822455827181305858
#
#                                                    Tweet      Username
# 0      Election Day is in one week. Visit https://t.c...  TheDemocrats
# 1      This Native American Heritage Month, we recogn...  TheDemocrats
# ...

# %% [markdown]
# ## Creating the Democratic Party Tweet Dataframe

# %%
pdList1 = [dems1, dems2, dems3, dems4, dems5, dems6, dems7, dems8, dems9, dems10, dems11, dems12, 
           dems13, dems14, dems15, dems16, dems17, dems18, dems19, dems20, dems21, dems22, dems23]
dem_tw = pd.concat(pdList1)

# %%
dem_tw.head()
# Out:
#                        Date             Tweet ID  \
# 0 2022-11-01 13:55:03+00:00  1587443101790048258
# 1 2022-11-01 01:27:00+00:00  1587254848940085253
# 2 2022-10-31 22:30:02+00:00  1587210314663215105
# 3 2022-10-31 20:29:01+00:00  1587179858236305408
# 4 2022-10-31 18:22:05+00:00  1587147915050500103
#
#                                                Tweet  Username
# 0  One more week until Election Day. \n\nLet’s do...  JoeBiden
# 1  Democrats will protect Social Security.\nWe’ll...  JoeBiden
# 2  With Election Day right around the corner, I’m...  JoeBiden
# 3  I know which side I’m on.\nhttps://t.co/RBiVHJ...  JoeBiden
# 4  Make your plan to vote early or on Election Da...  JoeBiden

# %%
print(dem_tw.shape)
print(dem_tw.dtypes)
print(dem_tw.isna().sum())
# Out:
# (146664, 4)
# Date        datetime64[ns, UTC]
# Tweet ID                  int64
# Tweet                    object
# Username                 object
# dtype: object
# Date        0
# Tweet ID    0
# Tweet       0
# Username    0
# dtype: int64

# %%
dem_tw = dem_tw.sort_values(by='Date', ascending = True)
dem_tw = dem_tw.reset_index()
dem_tw = dem_tw.drop(columns=['index'])
dem_tw.Date = pd.to_datetime(dem_tw['Date'])
dem_tw.Date = dem_tw.Date.dt.strftime("%m/%d/%Y")
dem_tw.Date = pd.to_datetime(dem_tw['Date'])
dem_tw['Political_Score'] = 1

# %%
dem_tw
# Out:
#              Date             Tweet ID  \
# 0      2017-01-20   822232466786283521
# 1      2017-01-20   822240072951013376
# 2      2017-01-20   822242471883243520
# 3      2017-01-20   822243371561447424
# 4      2017-01-20   822248267853352960
# ...           ...                  ...
# 146659 2022-11-01  1587462060350357504
# 146660 2022-11-01  1587462065899425793
# 146661 2022-11-01  1587463481930006530
# 146662 2022-11-01  1587464191128002560
# 146663 2022-11-01  1587467028243386374
#
#                                                     Tweet        Username  \
# 0       Let us all stand up for people who deserve to ...    KamalaHarris
# 1       A very powerful read about the stories of our ...  PramilaJayapal
# 2       If heaven has a flaw, we're gonna find out soo...      SenSchumer
# 3       Barrett was a brilliant NY beacon, cleaning up...      SenSchumer
# 4       Positive conversation with @downtownseattle to...      RepJayapal
# ...

# %%
print(dem_tw.shape)
print(dem_tw.dtypes)
print(dem_tw.isna().sum())
# Out:
# (146664, 5)
# Date               datetime64[ns]
# Tweet ID                    int64
# Tweet                      object
# Username                   object
# Political_Score             int64
# dtype: object
# Date               0
# Tweet ID           0
# Tweet              0
# Username           0
# Political_Score    0
# dtype: int64

# %%
dem_tw.to_csv('Democratic Party Tweets')

# %% [markdown]
# ## Webscraping the Republican Party's Tweets

# %%
# %%time
trumpl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:realdonaldtrump since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    trumpl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop1 = pd.DataFrame(trumpl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop1
# Out:
# CPU times: user 62.7 ms, sys: 5 ms, total: 67.7 ms
# Wall time: 532 ms
# Empty DataFrame
# Columns: [Date, Tweet ID, Tweet, Username]
# Index: []

# %%
# %%time
trumpl2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:POTUS45 since:2017-01-20 until:2021-1-19 lang:en').get_items()):
    if i == maxTweets:
        break
    trumpl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop2 = pd.DataFrame(trumpl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop2
# Out:
# CPU times: user 496 ms, sys: 33.3 ms, total: 530 ms
# Wall time: 8.95 s
#                          Date             Tweet ID  \
# 0   2018-06-01 17:28:09+00:00  1002602715820756993
# 1   2018-01-31 06:18:32+00:00   958585268252102656
# 2   2017-12-01 21:32:52+00:00   936709709641502725
# 3   2017-11-29 20:15:28+00:00   935965452810977280
# 4   2017-11-01 17:04:25+00:00   925770515071021056
# ..                        ...                  ...
# 373 2017-01-21 17:18:05+00:00   822855801400414211
# 374 2017-01-21 02:25:43+00:00   822631230944460801
# 375 2017-01-21 00:47:49+00:00   822606593808277504
# 376 2017-01-20 22:32:17+00:00   822572484742488065
# 377 2017-01-20 19:11:33+00:00   822521968465416192
#
#                                                  Tweet Username
# 0    Record JOBS DAY!! 223K jobs added. Unemploymen...  POTUS45
# 1    THANK YOU @SteveScalise!\n#SOTU #TeamScalise h...  POTUS45
# 2    Thank you @SecretaryZinke! https://t.co/r84hnW...  POTUS45
# ...

# %%
# %%time
trumpl3 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:DonaldJTrumpJr since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    trumpl3.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop3 = pd.DataFrame(trumpl3, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop3
# Out:
# CPU times: user 14.3 s, sys: 597 ms, total: 14.9 s
# Wall time: 5min 7s
#                            Date             Tweet ID  \
# 0     2022-11-01 14:21:00+00:00  1587449632581472257
# 1     2022-10-31 19:53:34+00:00  1587170938403127296
# 2     2022-10-31 18:52:42+00:00  1587155619613528064
# 3     2022-10-31 12:39:42+00:00  1587061753434689536
# 4     2022-10-31 01:55:31+00:00  1586899639831171072
# ...                         ...                  ...
# 10148 2017-01-20 13:39:02+00:00   822438289114337281
# 10149 2017-01-20 13:28:04+00:00   822435528989638656
# 10150 2017-01-20 03:45:03+00:00   822288805868818433
# 10151 2017-01-20 01:26:33+00:00   822253951345184770
# 10152 2017-01-20 01:22:47+00:00   822253003059134465
#
#                                                    Tweet        Username
# 0      The media really think people are stupid enoug...  DonaldJTrumpJr
# 1      Wait, so you’re saying if we actually enforced...  DonaldJTrumpJr
# ...

# %%
# %%time
pencel1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:VP45 since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    pencel1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop4 = pd.DataFrame(pencel1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop4
# Out:
# CPU times: user 6.59 s, sys: 327 ms, total: 6.92 s
# Wall time: 2min 6s
#                           Date             Tweet ID  \
# 0    2021-01-19 20:45:47+00:00  1351631964843999232
# 1    2020-01-01 15:14:45+00:00  1212391720610095106
# 2    2019-12-31 23:44:39+00:00  1212157651360079872
# 3    2019-12-29 20:14:33+00:00  1211380002559799297
# 4    2019-12-26 20:02:58+00:00  1210289923917529089
# ...                        ...                  ...
# 5203 2017-01-21 05:22:43+00:00   822675771055542272
# 5204 2017-01-20 22:58:50+00:00   822579166176509956
# 5205 2017-01-20 22:37:19+00:00   822573752093380608
# 5206 2017-01-20 20:09:15+00:00   822536488646742019
# 5207 2017-01-20 18:05:56+00:00   822505454450470912
#
#                                                   Tweet Username
# 0     Thank you for the privilege of serving as your...     VP45
# 1     In 2017, Speaker Pelosi called President @real...     VP45
# 2     A record year for America! The stock market cl...     VP45
# ...

# %%
# %%time
pencel2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Mike_Pence since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    pencel2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop5 = pd.DataFrame(pencel2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop5
# Out:
# CPU times: user 4.52 s, sys: 226 ms, total: 4.75 s
# Wall time: 1min 25s
#                           Date             Tweet ID  \
# 0    2022-11-01 00:39:47+00:00  1587242968645341184
# 1    2022-10-31 19:56:37+00:00  1587171704794763265
# 2    2022-10-31 17:23:20+00:00  1587133130405994496
# 3    2022-10-31 15:02:56+00:00  1587097796766621701
# 4    2022-10-31 15:00:56+00:00  1587097295903932419
# ...                        ...                  ...
# 3504 2017-01-20 14:50:42+00:00   822456321433894912
# 3505 2017-01-20 14:17:22+00:00   822447933899599872
# 3506 2017-01-20 04:21:43+00:00   822298032842637312
# 3507 2017-01-20 04:09:05+00:00   822294855611191296
# 3508 2017-01-20 02:36:58+00:00   822271673206444032
#
#                                                   Tweet    Username
# 0     Mike Pence: Dems Are the Extremists: ‘Abortion...  Mike_Pence
# 1     Precious Memories of Trick or Treating in days...  Mike_Pence
# ...

# %%
# %%time
cruzl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:tedcruz since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    cruzl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop6 = pd.DataFrame(cruzl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop6
# Out:
# CPU times: user 13.9 s, sys: 561 ms, total: 14.4 s
# Wall time: 4min 58s
#                           Date             Tweet ID  \
# 0    2022-11-01 15:33:12+00:00  1587467803124285440
# 1    2022-11-01 13:58:44+00:00  1587444027741331462
# 2    2022-11-01 12:39:00+00:00  1587423962509627393
# 3    2022-11-01 03:12:19+00:00  1587281352507916288
# 4    2022-11-01 01:53:49+00:00  1587261597738745857
# ...                        ...                  ...
# 9839 2017-01-24 19:16:15+00:00   823972699970084864
# 9840 2017-01-23 20:05:58+00:00   823622826150293505
# 9841 2017-01-23 14:55:34+00:00   823544711881359361
# 9842 2017-01-23 14:55:04+00:00   823544584072466434
# 9843 2017-01-20 18:00:32+00:00   822504097555345409
#
#                                                   Tweet Username
# 0     Skip the corrupt corporate media’s bias, liste...  tedcruz
# 1     Lots of editorializing in this “news”article, ...  tedcruz
# 2     Don’t miss the latest episode of #Verdict wher...  tedcruz
# ...

# %%
# %%time
cruzl2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenTedCruz since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    cruzl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop7 = pd.DataFrame(cruzl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop7
# Out:
# CPU times: user 14.2 s, sys: 709 ms, total: 14.9 s
# Wall time: 4min 39s
#                            Date             Tweet ID  \
# 0     2022-11-01 15:56:08+00:00  1587473573354119168
# 1     2022-11-01 14:30:35+00:00  1587452045145116674
# 2     2022-10-31 22:50:00+00:00  1587215338180997120
# 3     2022-10-31 21:47:38+00:00  1587199645293363201
# 4     2022-10-31 21:47:38+00:00  1587199643426988032
# ...                         ...                  ...
# 11076 2017-01-23 20:52:19+00:00   823634489834405888
# 11077 2017-01-20 23:51:34+00:00   822592436283277313
# 11078 2017-01-20 18:50:14+00:00   822516604961488896
# 11079 2017-01-20 11:53:04+00:00   822411617786855424
# 11080 2017-01-20 10:32:03+00:00   822391232404004864
#
#                                                    Tweet    Username
# 0      President Biden threatening the American energ...  SenTedCruz
# 1      RELEASE: Cruz Statement on Oral Arguments in S...  SenTedCruz
# ...

# %%
# %%time
rubiol1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:marcorubio since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    rubiol1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop8 = pd.DataFrame(rubiol1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop8
# Out:
# CPU times: user 10.9 s, sys: 538 ms, total: 11.4 s
# Wall time: 3min 46s
#                           Date             Tweet ID  \
# 0    2022-10-31 23:57:43+00:00  1587232382045851653
# 1    2022-10-31 21:10:09+00:00  1587190212542795782
# 2    2022-10-31 17:18:11+00:00  1587131835401781249
# 3    2022-10-30 03:40:30+00:00  1586563667927113729
# 4    2022-10-28 17:54:30+00:00  1586053808433823744
# ...                        ...                  ...
# 8969 2017-01-27 18:32:37+00:00   825048883755638787
# 8970 2017-01-25 17:12:06+00:00   824303846423937026
# 8971 2017-01-20 12:27:29+00:00   822420281381752832
# 8972 2017-01-20 12:23:47+00:00   822419351273881605
# 8973 2017-01-20 00:33:02+00:00   822240484877799425
#
#                                                   Tweet    Username
# 0     In Polk County #Florida lots of enthusiasm for...  marcorubio
# 1     The #RedWave2022 is coming to #Florida &amp; i...  marcorubio
# ...

# %%
# %%time
rubiol2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenRubioPress since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    rubiol2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop9 = pd.DataFrame(rubiol2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop9
# Out:
# CPU times: user 10.2 s, sys: 544 ms, total: 10.8 s
# Wall time: 3min 37s
#                           Date             Tweet ID  \
# 0    2022-11-01 15:46:38+00:00  1587471182374240257
# 1    2022-11-01 14:37:40+00:00  1587453827770458114
# 2    2022-10-31 19:21:11+00:00  1587162788157333505
# 3    2022-10-31 17:13:06+00:00  1587130555812007936
# 4    2022-10-28 17:16:04+00:00  1586044137169899521
# ...                        ...                  ...
# 8440 2017-01-24 02:31:07+00:00   823719752145272832
# 8441 2017-01-24 00:36:25+00:00   823690884751519745
# 8442 2017-01-23 23:01:24+00:00   823666973385035778
# 8443 2017-01-23 21:56:42+00:00   823650694628577280
# 8444 2017-01-23 18:53:50+00:00   823604674423128064
#
#                                                   Tweet       Username
# 0     As we begin Military Family Month, Senator Rub...  SenRubioPress
# 1     Happy Independence Day to the people of Antigu...  SenRubioPress
# ...

# %%
# %%time
mcconnelll1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:LeaderMcConnell since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    mcconnelll1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop10 = pd.DataFrame(mcconnelll1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop10
# Out:
# CPU times: user 3.46 s, sys: 205 ms, total: 3.66 s
# Wall time: 1min 11s
#                           Date             Tweet ID  \
# 0    2022-10-30 17:15:59+00:00  1586768892311076873
# 1    2022-10-28 15:31:05+00:00  1586017719912210440
# 2    2022-10-13 16:47:45+00:00  1580601193767632903
# 3    2022-10-03 01:49:19+00:00  1576751218810318848
# 4    2022-09-28 17:40:50+00:00  1575178736785584129
# ...                        ...                  ...
# 3153 2017-01-20 22:53:45+00:00   822577885819047939
# 3154 2017-01-20 17:00:19+00:00   822488942872240128
# 3155 2017-01-20 16:54:33+00:00   822487492469391361
# 3156 2017-01-20 16:52:56+00:00   822487085282185218
# 3157 2017-01-20 14:42:20+00:00   822454216174292992
#
#                                                   Tweet         Username
# 0     Elaine and I are terribly saddened by the pass...  LeaderMcConnell
# 1     Horrified and disgusted by the reports that Pa...  LeaderMcConnell
# ...

# %%
# %%time
mcconnelll2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:McConnellPress since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    mcconnelll2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop11 = pd.DataFrame(mcconnelll2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop11
# Out:
# CPU times: user 7.11 s, sys: 350 ms, total: 7.46 s
# Wall time: 2min 30s
#                           Date             Tweet ID  \
# 0    2022-11-01 15:27:28+00:00  1587466361181245443
# 1    2022-10-30 20:37:26+00:00  1586819588448190467
# 2    2022-10-27 18:34:24+00:00  1585701465456316421
# 3    2022-10-27 17:37:29+00:00  1585687141132140547
# 4    2022-10-27 17:25:07+00:00  1585684029176676354
# ...                        ...                  ...
# 5705 2017-01-24 18:17:36+00:00   823957941543993344
# 5706 2017-01-24 00:00:02+00:00   823681730683006980
# 5707 2017-01-23 21:55:08+00:00   823650299760037889
# 5708 2017-01-23 20:09:51+00:00   823623803834142721
# 5709 2017-01-23 19:30:04+00:00   823613790281404417
#
#                                                   Tweet        Username
# 0     .@LeaderMcConnell comments on the tragic death...  McConnellPress
# 1     .@LeaderMcConnell: I was heartbroken to learn ...  McConnellPress
# ...

# %%
# %%time
mccarthyl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:GOPLeader since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    mccarthyl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop12 = pd.DataFrame(mccarthyl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop12
# Out:
# CPU times: user 6.27 s, sys: 323 ms, total: 6.59 s
# Wall time: 2min 8s
#                           Date             Tweet ID  \
# 0    2022-11-01 12:57:58+00:00  1587428736122597377
# 1    2022-10-31 18:56:00+00:00  1587156449897156610
# 2    2022-10-31 13:55:26+00:00  1587080809898741761
# 3    2022-10-27 22:50:34+00:00  1585765931845836800
# 4    2022-10-27 17:06:22+00:00  1585679308626034694
# ...                        ...                  ...
# 5059 2017-01-25 14:56:05+00:00   824269618621583361
# 5060 2017-01-24 22:07:49+00:00   824015878236897281
# 5061 2017-01-24 17:17:05+00:00   823942712374067200
# 5062 2017-01-23 18:04:01+00:00   823592134993412098
# 5063 2017-01-20 17:04:27+00:00   822489980589187073
#
#                                                   Tweet   Username
# 0     Only one party says:\n- Only women should comp...  GOPLeader
# 1     Republicans have the right plan to make Americ...  GOPLeader
# ...

# %%
# %%time
gosarl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RepGosar since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    gosarl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop13 = pd.DataFrame(gosarl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop13
# Out:
# CPU times: user 5.99 s, sys: 297 ms, total: 6.29 s
# Wall time: 2min 4s
#                           Date             Tweet ID  \
# 0    2022-10-31 21:35:27+00:00  1587196579865239552
# 1    2022-10-31 17:07:44+00:00  1587129206537961474
# 2    2022-10-30 23:45:18+00:00  1586866868719001600
# 3    2022-10-30 22:24:38+00:00  1586846569139159040
# 4    2022-10-30 19:49:35+00:00  1586807549038313474
# ...                        ...                  ...
# 4711 2017-01-23 05:08:04+00:00   823396860337541120
# 4712 2017-01-22 13:09:09+00:00   823155542554267653
# 4713 2017-01-20 19:02:38+00:00   822519723451621380
# 4714 2017-01-20 17:01:28+00:00   822489230366691328
# 4715 2017-01-20 16:01:24+00:00   822474116494229504
#
#                                                   Tweet  Username
# 0     America First is a winning message.\n\nAmerica...  RepGosar
# 1     Elon Musk buying Twitter is a great developmen...  RepGosar
# 2                         Pray for President Bolsonaro.  RepGosar
# ...

# %%
# %%time
gosarl2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:DrPaulGosar since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    gosarl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop14 = pd.DataFrame(gosarl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop14
# Out:
# CPU times: user 5.74 s, sys: 239 ms, total: 5.98 s
# Wall time: 2min 12s
#                           Date             Tweet ID  \
# 0    2022-11-01 14:42:36+00:00  1587455068558630914
# 1    2022-10-31 21:40:35+00:00  1587197869613793284
# 2    2022-10-31 21:40:34+00:00  1587197865901842432
# 3    2022-10-31 02:14:53+00:00  1586904510525427713
# 4    2022-10-31 01:56:30+00:00  1586899886452129792
# ...                        ...                  ...
# 3965 2017-06-10 14:03:07+00:00   873541038325084160
# 3966 2017-06-08 16:28:24+00:00   872852821972070400
# 3967 2017-06-08 14:46:36+00:00   872827206032130048
# 3968 2017-06-08 13:54:11+00:00   872814013142491136
# 3969 2017-06-07 10:24:29+00:00   872398852992753664
#
#                                                   Tweet     Username
# 0     Great news for Arizona and America—@bgmasters ...  DrPaulGosar
# 1     2. “In 2014, he received just under 70% of the...  DrPaulGosar
# ...

# %%
# %%time
greenel1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RepMTG since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    greenel1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop15 = pd.DataFrame(greenel1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop15
# Out:
# CPU times: user 2.52 s, sys: 142 ms, total: 2.66 s
# Wall time: 52 s
#                           Date             Tweet ID  \
# 0    2022-11-01 15:01:18+00:00  1587459772554649601
# 1    2022-10-31 14:04:32+00:00  1587083100961619968
# 2    2022-10-31 13:38:51+00:00  1587076636477882373
# 3    2022-10-31 13:10:28+00:00  1587069494807203847
# 4    2022-10-31 13:10:28+00:00  1587069493184008194
# ...                        ...                  ...
# 2014 2021-01-04 01:51:28+00:00  1345910688624078851
# 2015 2021-01-03 22:20:02+00:00  1345857478576234496
# 2016 2021-01-03 20:03:29+00:00  1345823114425413634
# 2017 2021-01-03 17:00:31+00:00  1345777071688183809
# 2018 2021-01-03 01:08:01+00:00  1345537364375064577
#
#                                                   Tweet Username
# 0     David Depape was an illegal alien that oversta...   RepMTG
# 1     The same mainstream media democrat activists t...   RepMTG
# 2                Make America energy independent AGAIN!   RepMTG
# ...

# %%
# %%time
paull1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RandPaul since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    paull1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop16 = pd.DataFrame(paull1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop16
# Out:
# CPU times: user 4.79 s, sys: 247 ms, total: 5.04 s
# Wall time: 1min 31s
#                           Date             Tweet ID  \
# 0    2022-11-01 16:21:59+00:00  1587480078228791301
# 1    2022-11-01 15:44:06+00:00  1587470546513846273
# 2    2022-11-01 15:12:22+00:00  1587462561376747521
# 3    2022-11-01 14:15:59+00:00  1587448369919795205
# 4    2022-11-01 13:17:18+00:00  1587433603256156165
# ...                        ...                  ...
# 3848 2017-01-27 17:02:25+00:00   825026185147080704
# 3849 2017-01-24 00:25:19+00:00   823688092028719112
# 3850 2017-01-24 00:16:21+00:00   823685837476995072
# 3851 2017-01-21 21:04:29+00:00   822912777815752706
# 3852 2017-01-20 13:48:59+00:00   822440790182006786
#
#                                                   Tweet  Username
# 0     Huge crowd in Elizabethtown ready for a red wa...  RandPaul
# 1     We dehumanize everyone in politics. We should ...  RandPaul
# 2     Thank you Georgetown for coming out to rally f...  RandPaul
# ...

# %%
# %%time
cottonl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenTomCotton since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    cottonl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop17 = pd.DataFrame(cottonl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop17
# Out:
# CPU times: user 5.62 s, sys: 347 ms, total: 5.97 s
# Wall time: 1min 58s
#                           Date             Tweet ID  \
# 0    2022-10-27 13:43:02+00:00  1585628138670903297
# 1    2022-10-25 16:34:20+00:00  1584946471295930368
# 2    2022-10-21 18:47:49+00:00  1583530511137243138
# 3    2022-10-19 18:16:27+00:00  1582797842946887681
# 4    2022-10-19 13:53:10+00:00  1582731585513668608
# ...                        ...                  ...
# 4948 2017-01-20 15:43:28+00:00   822469600730288129
# 4949 2017-01-20 14:27:56+00:00   822450593910419457
# 4950 2017-01-20 12:39:50+00:00   822423390963240960
# 4951 2017-01-20 11:59:34+00:00   822413256690200577
# 4952 2017-01-20 11:13:51+00:00   822401752561582080
#
#                                                   Tweet      Username
# 0     Reminder: Washington D.C. wants to let illegal...  SenTomCotton
# 1     Thank you to the law enforcement and healthcar...  SenTomCotton
# ...

# %%
# %%time
cottonl2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:TomCottonAR since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    cottonl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop18 = pd.DataFrame(cottonl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop18
# Out:
# CPU times: user 5.18 s, sys: 265 ms, total: 5.45 s
# Wall time: 1min 45s
#                           Date             Tweet ID  \
# 0    2022-11-01 14:58:25+00:00  1587459047359479809
# 1    2022-11-01 14:20:13+00:00  1587449433972776962
# 2    2022-11-01 12:59:15+00:00  1587429058807201794
# 3    2022-11-01 12:49:39+00:00  1587426644960198658
# 4    2022-11-01 00:53:30+00:00  1587246420045824000
# ...                        ...                  ...
# 3919 2017-01-26 17:46:06+00:00   824674790153875456
# 3920 2017-01-24 12:56:46+00:00   823877200852160513
# 3921 2017-01-24 02:42:23+00:00   823722586186063872
# 3922 2017-01-21 20:44:57+00:00   822907858580893696
# 3923 2017-01-20 03:59:40+00:00   822292484936110081
#
#                                                   Tweet     Username
# 0     The Biden Admin is STILL trying to force toddl...  TomCottonAR
# 1     Great to be on @foxandfriends to talk about ho...  TomCottonAR
# ...

# %%
# %%time
scottl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:SenRickScott since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    scottl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop19 = pd.DataFrame(scottl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop19
# Out:
# CPU times: user 14.4 s, sys: 704 ms, total: 15.1 s
# Wall time: 5min 2s
#                            Date             Tweet ID  \
# 0     2022-11-01 16:32:26+00:00  1587482708128694272
# 1     2022-11-01 15:01:47+00:00  1587459896349495296
# 2     2022-11-01 13:20:00+00:00  1587434280757514241
# 3     2022-11-01 00:29:53+00:00  1587240473919365122
# 4     2022-10-31 20:57:02+00:00  1587186909788479488
# ...                         ...                  ...
# 10934 2017-01-20 16:54:42+00:00   822487529941254145
# 10935 2017-01-20 15:45:01+00:00   822469991811321858
# 10936 2017-01-20 15:33:40+00:00   822467136367063046
# 10937 2017-01-20 15:19:42+00:00   822463619501883395
# 10938 2017-01-20 14:43:31+00:00   822454515584684032
#
#                                                    Tweet      Username
# 0      📰 IN THE NEWS: Rick Scott, Marco Rubio urge NO...  SenRickScott
# 1      Happy Birthday, @MaElviraSalazar! \n\nThanks f...  SenRickScott
# ...

# %%
# %%time
scottl2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:ScottforFlorida since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    scottl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop20 = pd.DataFrame(scottl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop20
# Out:
# CPU times: user 2.9 s, sys: 156 ms, total: 3.05 s
# Wall time: 57.5 s
#                           Date             Tweet ID  \
# 0    2022-11-01 13:58:06+00:00  1587443868131381249
# 1    2022-11-01 12:02:40+00:00  1587414820890066944
# 2    2022-10-31 23:36:53+00:00  1587227137563557888
# 3    2022-10-31 21:17:53+00:00  1587192155839275009
# 4    2022-10-31 11:53:16+00:00  1587050067336347649
# ...                        ...                  ...
# 2213 2017-02-02 17:23:58+00:00   827205937861627904
# 2214 2017-01-27 18:15:19+00:00   825044530865065984
# 2215 2017-01-25 15:24:28+00:00   824276759852027905
# 2216 2017-01-23 23:16:01+00:00   823670654071410689
# 2217 2017-01-23 21:55:38+00:00   823650424435646467
#
#                                                   Tweet         Username
# 0     Welcome to Florida, @JoeBiden.\n\nLook forward...  ScottforFlorida
# 1     📻 Joining @NHTodayShow with Christopher Ryan a...  ScottforFlorida
# ...

# %%
# %%time
jordanl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:Jim_Jordan since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    jordanl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop21 = pd.DataFrame(jordanl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop21
# Out:
# CPU times: user 4.53 s, sys: 247 ms, total: 4.77 s
# Wall time: 1min 25s
#                           Date             Tweet ID  \
# 0    2022-11-01 16:16:17+00:00  1587478645676949504
# 1    2022-11-01 15:14:06+00:00  1587462996909084682
# 2    2022-11-01 13:04:46+00:00  1587430446505287680
# 3    2022-11-01 01:40:02+00:00  1587258128978018308
# 4    2022-10-31 22:08:48+00:00  1587204971933696000
# ...                        ...                  ...
# 3679 2017-01-27 17:41:32+00:00   825036030562611201
# 3680 2017-01-27 16:40:35+00:00   825020692840091648
# 3681 2017-01-25 21:19:19+00:00   824366059234934786
# 3682 2017-01-25 21:17:46+00:00   824365670137729024
# 3683 2017-01-20 18:13:34+00:00   822507374367952896
#
#                                                   Tweet    Username
# 0     We going to make sure that the #SCOTUS decisio...  Jim_Jordan
# 1                              Make America Safe Again.  Jim_Jordan
# ...

# %%
# %%time
boebertl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:laurenboebert since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    boebertl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop22 = pd.DataFrame(boebertl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop22
# Out:
# CPU times: user 7.01 s, sys: 432 ms, total: 7.44 s
# Wall time: 2min 24s
#                           Date             Tweet ID  \
# 0    2022-11-01 16:51:11+00:00  1587487427681214467
# 1    2022-11-01 15:16:26+00:00  1587463582563844096
# 2    2022-11-01 13:30:52+00:00  1587437017415155712
# 3    2022-11-01 11:52:02+00:00  1587412144894640128
# 4    2022-11-01 01:55:50+00:00  1587262106864218112
# ...                        ...                  ...
# 6165 2019-12-09 17:31:27+00:00  1204091198572384270
# 6166 2019-12-09 13:09:05+00:00  1204025174212915204
# 6167 2019-12-09 12:51:11+00:00  1204020666166497282
# 6168 2019-12-08 22:10:49+00:00  1203799117945810952
# 6169 2019-12-08 21:57:00+00:00  1203795639945121793
#
#                                                   Tweet       Username
# 0     .@JoeRogan gets it. Every horrible policy prop...  laurenboebert
# 1     While the Left wants to make this election abo...  laurenboebert
# ...

# %%
# %%time
boebertl2 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:RepBoebert since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    boebertl2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop23 = pd.DataFrame(boebertl2, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop23
# Out:
# CPU times: user 1.67 s, sys: 101 ms, total: 1.77 s
# Wall time: 31.5 s
#                           Date             Tweet ID  \
# 0    2022-11-01 16:37:28+00:00  1587483977794846726
# 1    2022-11-01 15:30:50+00:00  1587467205280759809
# 2    2022-11-01 14:08:13+00:00  1587446416712126464
# 3    2022-10-31 21:57:19+00:00  1587202079256453122
# 4    2022-10-31 19:41:10+00:00  1587167818277158912
# ...                        ...                  ...
# 1326 2021-01-04 01:23:03+00:00  1345903535163138048
# 1327 2021-01-04 00:37:46+00:00  1345892141449543681
# 1328 2021-01-03 19:09:52+00:00  1345809620560994306
# 1329 2021-01-03 17:30:54+00:00  1345784718177038337
# 1330 2021-01-03 14:20:39+00:00  1345736838779179010
#
#                                                   Tweet    Username
# 0     The border crisis created the fentanyl epidemi...  RepBoebert
# 1     Read more here to learn about the important wo...  RepBoebert
# ...

# %%
# %%time
gopl1 = []
maxTweets = 100000
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:GOP since:2017-01-20 lang:en').get_items()):
    if i == maxTweets:
        break
    gopl1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
gop24 = pd.DataFrame(gopl1, columns=['Date', 'Tweet ID', 'Tweet', 'Username'])

gop24
# Out:
# CPU times: user 22.7 s, sys: 1.3 s, total: 24 s
# Wall time: 7min 48s
#                            Date             Tweet ID  \
# 0     2022-11-01 15:04:01+00:00  1587460458608459789
# 1     2022-11-01 13:49:00+00:00  1587441578779385857
# 2     2022-11-01 11:11:00+00:00  1587401816647426049
# 3     2022-11-01 09:25:00+00:00  1587375142824468480
# 4     2022-11-01 07:34:00+00:00  1587347207598006274
# ...                         ...                  ...
# 19142 2017-01-20 23:28:44+00:00   822586691995181058
# 19143 2017-01-20 22:36:08+00:00   822573453110874113
# 19144 2017-01-20 17:00:37+00:00   822489015886741504
# 19145 2017-01-20 16:54:43+00:00   822487532864737286
# 19146 2017-01-20 14:12:02+00:00   822446591399395328
#
#                                                    Tweet Username
# 0      Awesome work @NJGOPField &amp; @NJGOP!\n\nKeep...      GOP
# 1      7️⃣7️⃣7️⃣7️⃣7️⃣7️⃣7️⃣\n\n1 week until election...      GOP
# ...

# %% [markdown]
# ## Creating the Republican Party Tweet Dataframe

# %%
pdList2 = [gop1, gop2, gop3, gop4, gop5, gop6, gop7, gop8, gop9, gop10, gop11, gop12, 
           gop13, gop14, gop15, gop16, gop17, gop18, gop19, gop20, gop21, gop22, gop23, gop24]
gop_tw = pd.concat(pdList2)

# %%
gop_tw.head()
# Out:
#                        Date             Tweet ID  \
# 0 2018-06-01 17:28:09+00:00  1002602715820756993
# 1 2018-01-31 06:18:32+00:00   958585268252102656
# 2 2017-12-01 21:32:52+00:00   936709709641502725
# 3 2017-11-29 20:15:28+00:00   935965452810977280
# 4 2017-11-01 17:04:25+00:00   925770515071021056
#
#                                                Tweet Username
# 0  Record JOBS DAY!! 223K jobs added. Unemploymen...  POTUS45
# 1  THANK YOU @SteveScalise!\n#SOTU #TeamScalise h...  POTUS45
# 2  Thank you @SecretaryZinke! https://t.co/r84hnW...  POTUS45
# 3  Just arrived in Missouri. Heading to St. Charl...  POTUS45
# 4  Opening remarks at this afternoons @Cabinet me...  POTUS45

# %%
print(gop_tw.shape)
print(gop_tw.dtypes)
print(gop_tw.isna().sum())
# Out:
# (138448, 4)
# Date        datetime64[ns, UTC]
# Tweet ID                 object
# Tweet                    object
# Username                 object
# dtype: object
# Date        0
# Tweet ID    0
# Tweet       0
# Username    0
# dtype: int64

# %%
gop_tw['Tweet ID'] = gop_tw['Tweet ID'].astype(int)
gop_tw = gop_tw.sort_values(by='Date', ascending = True)
gop_tw = gop_tw.reset_index()
gop_tw = gop_tw.drop(columns=['index'])
gop_tw.Date = pd.to_datetime(gop_tw['Date'])
gop_tw.Date = gop_tw.Date.dt.strftime("%m/%d/%Y")
gop_tw.Date = pd.to_datetime(gop_tw['Date'])
gop_tw['Political_Score'] = 0

# %%
gop_tw
# Out:
#              Date             Tweet ID  \
# 0      2017-01-20   822240484877799425
# 1      2017-01-20   822253003059134465
# 2      2017-01-20   822253951345184770
# 3      2017-01-20   822271673206444032
# 4      2017-01-20   822288805868818433
# ...           ...                  ...
# 138443 2022-11-01  1587478645676949504
# 138444 2022-11-01  1587480078228791301
# 138445 2022-11-01  1587482708128694272
# 138446 2022-11-01  1587483977794846726
# 138447 2022-11-01  1587487427681214467
#
#                                                     Tweet        Username  \
# 0       @MomToBea @GloryCorinne I have serious concern...      marcorubio
# 1       #Repost foxnews\n・・・\nViewers enjoyed a specta...  DonaldJTrumpJr
# 2       #Repost @ivankatrump\n・・・\nOn the steps of the...  DonaldJTrumpJr
# 3       So very proud of my wife, Karen. She was an am...      Mike_Pence
# 4       Couldn't resist breaking out the camera for th...  DonaldJTrumpJr
# ...

# %%
print(gop_tw.shape)
print(gop_tw.dtypes)
print(gop_tw.isna().sum())
# Out:
# (138448, 5)
# Date               datetime64[ns]
# Tweet ID                    int64
# Tweet                      object
# Username                   object
# Political_Score             int64
# dtype: object
# Date               0
# Tweet ID           0
# Tweet              0
# Username           0
# Political_Score    0
# dtype: int64

# %%
gop_tw.to_csv('Republican Party Tweets')

# %% [markdown]
# ## Creating our Dataframe

# %%
dfs = [dem_tw, gop_tw]
df = pd.concat(dfs)
df
# Out:
#              Date             Tweet ID  \
# 0      2017-01-20   822232466786283521
# 1      2017-01-20   822240072951013376
# 2      2017-01-20   822242471883243520
# 3      2017-01-20   822243371561447424
# 4      2017-01-20   822248267853352960
# ...           ...                  ...
# 138443 2022-11-01  1587478645676949504
# 138444 2022-11-01  1587480078228791301
# 138445 2022-11-01  1587482708128694272
# 138446 2022-11-01  1587483977794846726
# 138447 2022-11-01  1587487427681214467
#
#                                                     Tweet        Username  \
# 0       Let us all stand up for people who deserve to ...    KamalaHarris
# 1       A very powerful read about the stories of our ...  PramilaJayapal
# 2       If heaven has a flaw, we're gonna find out soo...      SenSchumer
# 3       Barrett was a brilliant NY beacon, cleaning up...      SenSchumer
# 4       Positive conversation with @downtownseattle to...      RepJayapal
# ...

# %%
print(df.shape)
print(df.dtypes)
print(df.isna().sum())
# Out:
# (285112, 5)
# Date               datetime64[ns]
# Tweet ID                    int64
# Tweet                      object
# Username                   object
# Political_Score             int64
# dtype: object
# Date               0
# Tweet ID           0
# Tweet              0
# Username           0
# Political_Score    0
# dtype: int64

# %%
df = df.sort_values(by='Date', ascending = True)
df = df.reset_index()
df = df.drop(columns=['index'])
df.Date = pd.to_datetime(df['Date'])

# %%
print(df.shape)
print(df.dtypes)
print(df.isna().sum())
# Out:
# (285112, 5)
# Date               datetime64[ns]
# Tweet ID                    int64
# Tweet                      object
# Username                   object
# Political_Score             int64
# dtype: object
# Date               0
# Tweet ID           0
# Tweet              0
# Username           0
# Political_Score    0
# dtype: int64

# %%
df
# Out:
#              Date             Tweet ID  \
# 0      2017-01-20   822232466786283521
# 1      2017-01-20   822487532864737286
# 2      2017-01-20   822488942872240128
# 3      2017-01-20   822489015886741504
# 4      2017-01-20   822489230366691328
# ...           ...                  ...
# 285107 2022-11-01  1587235471188324353
# 285108 2022-11-01  1587467028243386374
# 285109 2022-11-01  1587483977794846726
# 285110 2022-11-01  1587257366055211009
# 285111 2022-11-01  1587487427681214467
#
#                                                     Tweet         Username  \
# 0       Let us all stand up for people who deserve to ...     KamalaHarris
# 1       The 48th Vice President of the United States o...              GOP
# 2       Congratulations to @realDonaldTrump on becomin...  LeaderMcConnell
# 3       The 45th President of the United States of Ame...              GOP
# 4                               President Donald J. Trump         RepGosar
# ...

# %%
df.to_csv('Capstone Project Dataframe')
